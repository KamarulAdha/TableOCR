# %% [markdown]
# # TableOCR using Tesseract, Paddle, Easy, Doctr🌹

# %%
import os
import cv2
from IPython.display import display_html, display
from PIL import Image as PILImage
from utils import display_borderless_tables

from img2table.document import Image
from img2table.ocr import TesseractOCR, PaddleOCR

# %%
img = Image("Documents/table.png")

# %%
# Tesseract OCR
from img2table.ocr import TesseractOCR
tesseract_ocr = TesseractOCR(n_threads=1, lang="eng")

# PaddleOCR
from img2table.ocr import PaddleOCR
paddle_ocr = PaddleOCR(lang="en", kw={"use_dilation": True})

# EasyOCR
from img2table.ocr import EasyOCR
easyocr = EasyOCR(lang=["en"], kw={"gpu": True})

# docTR
from img2table.ocr import DocTR
doctr = DocTR(detect_language=True, kw={"detect_orientation": True})
# Out:
# tesseract 5.3.4
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE4.1
#  Found OpenMP 201511
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8
#  Found libcurl/7.81.0 OpenSSL/3.0.2 zlib/1.2.11 brotli/1.0.9 zstd/1.4.8 libidn2/2.3.2 libpsl/0.21.0 (+libidn2/2.3.2) libssh/0.9.6/openssl/zlib nghttp2/1.43.0 librtmp/2.3 OpenLDAP/2.5.16

# %%
## Tesseract
display_img = display_borderless_tables(img=img, ocr=tesseract_ocr)

display(PILImage.fromarray(display_img))
display_html("<hr>", raw=True)
# Out:
# <PIL.Image.Image image mode=RGB size=2334x687>
# <hr>

# %%
## Paddle
display_img = display_borderless_tables(img=img, ocr=paddle_ocr)

display(PILImage.fromarray(display_img))
display_html("<hr>", raw=True)
# Out:
# <PIL.Image.Image image mode=RGB size=2334x687>
# <hr>

# %%
## EasyOCR
display_img = display_borderless_tables(img=img, ocr=easyocr)

display(PILImage.fromarray(display_img))
display_html("<hr>", raw=True)
# Out:
# <PIL.Image.Image image mode=RGB size=2334x687>
# <hr>

# %%
## docTR
display_img = display_borderless_tables(img=img, ocr=doctr)

display(PILImage.fromarray(display_img))
display_html("<hr>", raw=True)
# Out:
# <PIL.Image.Image image mode=RGB size=2334x687>
# <hr>

# %%
tables = img.extract_tables(ocr=paddle_ocr, borderless_tables=True)

# %%
for table in tables:
    print(table.df)
    print()
# Out:
#                  0         1     2                  3
# 0  As at\n1.1.2022  Acquired  Sold  As at\n31.12.2022
#
#                                     0            1            2
# 0           Tan Sri Azlan Mohd Zainol      240,000      240,000
# 1           Mohd Imran Mohamad Salim*      468,200      468,200
# 2     Tan Sri Mohamad Salim Fateh Din    1,388,800    1,388,800
# 3       Datuk Seri Amir Hamzah Azizan          667          667
# 4      Dato'Wan Kamaruzaman Wan Ahmad      286,875      286,875
# 5                            Indirect         None         None
# 6         Tan Sri Azlan Mohd Zainol**       60,000       60,000
# 7  Tan Sri Mohamad Salim Fateh Din***  691,624,394  691,624,394
#
#                                     0           1           2
# 0           Tan Sri Azlan Mohd Zainol      24,000      24,000
# 1                            Indirect        None        None
# 2         Tan Sri Azlan Mohd Zainol**       6,000       6,000
# ...
